# %%
# start of scraping homework
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    #subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# 3 Keys: Canadiens at Golden Knights, Game 1 of Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# Lightning hoping for more active defensemen to even Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# King Clancy Trophy winner to be announced before Game 1 of Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# Islanders stick to plan to defeat Lightning in Game 1
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Stanley Cup Playoffs Buzz: Golden Knights host Canadiens in Game 1
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# Stanley Cup Semifinals schedule
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Lightning own up to mistakes in Game 1 loss to Islanders
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Pacioretty downplays emotions of facing Canadiens in Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Price eager for another chance with Canadiens in Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Golden Knights would be 'foolish' to look past Canadiens in Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-12
# -----------------
# Evans could return for Canadiens during Stanley Cup Semifinals
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-12
# -----------------
# Stanley Cup Semifinals predictions
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Hall would benefit from signing contract with Bruins, Cassidy says
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# Perry's grit boosts Canadiens entering Semifinals against Golden Knights
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# NHL DFS player picks, projections, strategy
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# Hall wants to stay with Bruins, says fit more important than money
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Color of Hockey: Joslin makes history as first Black coach in NWHL
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-14
# -----------------
# NHL Awards winners to be revealed starting Monday
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Niagara Falls lighting up red, white and blue for Canadiens
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Actor Greenfield voices support for Islanders before Game 1
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-13
# -----------------
# Power, projected No. 1 pick in 2021 draft, considering return to Michigan
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# 2021 NHL Draft order set through first 27 picks
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Price of Canadiens MVP halfway through Stanley Cup Playoffs
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-12
# -----------------
# Long Island, Tampa politicians wager on Islanders-Lightning series
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-12
# -----------------
# Rask would miss start of next season for Bruins after hip surgery
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Brind'Amour, Evason, Quenneville named Jack Adams Award finalists
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# 'Quest for the Stanley Cup' continues with Lightning seeking good luck
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Fallon jokes about NHL player pictures on 'Tonight Show'
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# MacKinnon, Matthews, McDavid named Hart Trophy finalists
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
# -----------------
# Hamilton hoping for new contract, to 'keep going' with Hurricanes
# Varlamov, Islanders take 1-0 lead in Semifinals against Lightning
# 2021-06-11
